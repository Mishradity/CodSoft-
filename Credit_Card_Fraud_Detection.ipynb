# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
creditcard=pd.read_csv('creditcard.csv')

# %%
creditcard
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0        0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2        1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3        1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4        2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...    ...       ...       ...       ...       ...       ...       ...
# 3968  3617  1.134592  0.252051  0.488592  0.799826 -0.264819 -0.369918
# 3969  3621 -1.338671  1.080974  1.291196  0.719258  0.101320  0.053896
# 3970  3622 -0.339728 -2.417449  0.975517  2.537995 -1.720361  0.863005
# 3971  3623 -0.368639  0.947432  1.707755  0.932092  0.292956  0.189100
# 3972  3624 -0.663445  1.162921  1.508050  0.549405  0.231377 -0.106041
#
#             V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
creditcard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
creditcard.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3968  3617  1.134592  0.252051  0.488592  0.799826 -0.264819 -0.369918
# 3969  3621 -1.338671  1.080974  1.291196  0.719258  0.101320  0.053896
# 3970  3622 -0.339728 -2.417449  0.975517  2.537995 -1.720361  0.863005
# 3971  3623 -0.368639  0.947432  1.707755  0.932092  0.292956  0.189100
# 3972  3624 -0.663445  1.162921  1.508050  0.549405  0.231377 -0.106041
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 3968 -0.243365  0.049761  1.210818  ... -0.351115 -0.851463  0.186169
# 3969  0.001297 -0.917575  1.638510  ...  0.498030 -0.483932  0.037686
# 3970  0.032965  0.026764  2.487139  ...  0.391639  0.264432 -0.735031
# 3971  0.499330  0.132466  0.779412  ... -0.119045  0.056665 -0.172703
# 3972  0.817977 -0.387026  1.488054  ... -0.420337 -0.361357       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# round(creditcard.describe(),2).T

# %%
creditcard.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
creditcard.duplicated().sum()
# Out:
# 32

# %%
creditcard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
creditcard["Class"].value_counts()
# Out:
# Class
# 0.0    3970
# 1.0       2
# Name: count, dtype: int64

# %%
plt.figure(figsize = (20,12))
ax=sb.heatmap(creditcard.corr(), annot = True, fmt = '.2f')

for i in range(creditcard.shape[1] + 1):
    ax.axvline(i, color = 'black')
    ax.axhline(i, color = 'black')

# %%
def split_data_by_class(creditcard):
  legit = creditcard[creditcard.Class == 0]
  fraud = creditcard[creditcard.Class == 1]
  return legit, fraud

# %%
legit_df,fraud_df = split_data_by_class(creditcard)

# %%
legit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3970 entries, 0 to 3971
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    3970 non-null   int64
#  1   V1      3970 non-null   float64
#  2   V2      3970 non-null   float64
#  3   V3      3970 non-null   float64
#  4   V4      3970 non-null   float64
#  5   V5      3970 non-null   float64
#  6   V6      3970 non-null   float64
#  7   V7      3970 non-null   float64
#  8   V8      3970 non-null   float64
#  9   V9      3970 non-null   float64
#  10  V10     3970 non-null   float64
#  11  V11     3970 non-null   float64
#  12  V12     3970 non-null   float64
#  13  V13     3970 non-null   float64
#  14  V14     3970 non-null   float64
#  15  V15     3970 non-null   float64
#  16  V16     3970 non-null   float64
#  17  V17     3970 non-null   float64
#  18  V18     3970 non-null   float64
#  19  V19     3970 non-null   float64
#  20  V20     3970 non-null   float64
# ...

# %%
fraud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 541 to 623
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    2 non-null      int64
#  1   V1      2 non-null      float64
#  2   V2      2 non-null      float64
#  3   V3      2 non-null      float64
#  4   V4      2 non-null      float64
#  5   V5      2 non-null      float64
#  6   V6      2 non-null      float64
#  7   V7      2 non-null      float64
#  8   V8      2 non-null      float64
#  9   V9      2 non-null      float64
#  10  V10     2 non-null      float64
#  11  V11     2 non-null      float64
#  12  V12     2 non-null      float64
#  13  V13     2 non-null      float64
#  14  V14     2 non-null      float64
#  15  V15     2 non-null      float64
#  16  V16     2 non-null      float64
#  17  V17     2 non-null      float64
#  18  V18     2 non-null      float64
#  19  V19     2 non-null      float64
#  20  V20     2 non-null      float64
# ...

# %%
legit_df.describe().T
# Out:
#          count         mean          std        min         25%          50%  \
# Time    3970.0  1638.828463  1016.116165   0.000000  751.000000  1526.500000
# V1      3970.0    -0.332459     1.351427 -12.168192   -1.030606    -0.450774
# V2      3970.0     0.308935     1.179233 -15.732974   -0.154565     0.409390
# V3      3970.0     0.837446     0.980592 -12.389545    0.287300     0.884228
# V4      3970.0     0.011432     1.417390  -4.657545   -0.908527     0.099196
# V5      3970.0    -0.029468     1.207855 -32.092129   -0.574102    -0.090452
# V6      3970.0     0.053530     1.286757  -7.465603   -0.735029    -0.209420
# V7      3970.0     0.147357     1.090293 -11.164794   -0.278692     0.162196
# V8      3970.0    -0.071642     1.294919 -23.632502   -0.205412     0.028901
# V9      3970.0     0.056211     0.918043  -3.336805   -0.473875     0.032399
# V10     3970.0    -0.056230     0.992307  -6.042641   -0.549714    -0.140855
# ...

# %%
 new_legit_df = legit_df.sample(n=492)

# %%
print(new_legit_df)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 528    392 -2.153491  0.104021  1.459532 -1.613284 -1.071361  0.192161
# 272    193 -0.922515  0.841577  2.078000  1.373071  0.666526  0.779012
# 3393  2920 -0.937144  1.058155  0.882815 -2.139087  0.071852 -1.512325
# 3218  2793 -3.168768  3.200173 -1.325055  0.410851 -0.390977 -1.368632
# 3687  3147 -0.798655  0.364896  0.560912 -1.022860 -0.107471 -1.069836
# ...    ...       ...       ...       ...       ...       ...       ...
# 2495  2066 -0.814647  1.110905  0.861886 -0.435080  0.180154  0.800022
# 3776  3275  0.754326 -1.268480  0.335702 -0.106730 -0.626858  1.152636
# 3662  3136 -0.381974  0.646111  1.217326 -1.947167 -0.080117 -1.716499
# 2960  2502 -2.211187  0.678025  1.564969 -3.499936 -1.483841 -0.295939
# 2336  1877  1.239160 -0.117871  0.267483  0.591171 -0.243513  0.173979
#
#             V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
combine_df = pd.concat([new_legit_df, fraud_df], axis=0)
combine_df
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 528    392 -2.153491  0.104021  1.459532 -1.613284 -1.071361  0.192161
# 272    193 -0.922515  0.841577  2.078000  1.373071  0.666526  0.779012
# 3393  2920 -0.937144  1.058155  0.882815 -2.139087  0.071852 -1.512325
# 3218  2793 -3.168768  3.200173 -1.325055  0.410851 -0.390977 -1.368632
# 3687  3147 -0.798655  0.364896  0.560912 -1.022860 -0.107471 -1.069836
# ...    ...       ...       ...       ...       ...       ...       ...
# 3662  3136 -0.381974  0.646111  1.217326 -1.947167 -0.080117 -1.716499
# 2960  2502 -2.211187  0.678025  1.564969 -3.499936 -1.483841 -0.295939
# 2336  1877  1.239160 -0.117871  0.267483  0.591171 -0.243513  0.173979
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
combine_df["Class"].value_counts()
# Out:
# Class
# 0.0    492
# 1.0      2
# Name: count, dtype: int64

# %%
ax = sb.countplot(x="Class", data=combine_df, width =0.3)
ax.set_title("Distribution of Transactions")
plt.xlabel("Type of Transaction")
plt.ylabel("Number of Transactions")

for i in ax.containers:
  ax.bar_label(i,)
  plt.show()

# %%
x = combine_df.drop(columns = "Class",axis = 1)
y = combine_df["Class"]

# %%
x
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 528    392 -2.153491  0.104021  1.459532 -1.613284 -1.071361  0.192161
# 272    193 -0.922515  0.841577  2.078000  1.373071  0.666526  0.779012
# 3393  2920 -0.937144  1.058155  0.882815 -2.139087  0.071852 -1.512325
# 3218  2793 -3.168768  3.200173 -1.325055  0.410851 -0.390977 -1.368632
# 3687  3147 -0.798655  0.364896  0.560912 -1.022860 -0.107471 -1.069836
# ...    ...       ...       ...       ...       ...       ...       ...
# 3662  3136 -0.381974  0.646111  1.217326 -1.947167 -0.080117 -1.716499
# 2960  2502 -2.211187  0.678025  1.564969 -3.499936 -1.483841 -0.295939
# 2336  1877  1.239160 -0.117871  0.267483  0.591171 -0.243513  0.173979
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
y
# Out:
# 528     0.0
# 272     0.0
# 3393    0.0
# 3218    0.0
# 3687    0.0
#        ...
# 3662    0.0
# 2960    0.0
# 2336    0.0
# 541     1.0
# 623     1.0
# Name: Class, Length: 494, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25, random_state = 2)
print(x_train)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 86      55 -0.773450  0.853112  0.818254 -0.236070  0.803463 -1.438728
# 585    438  1.287087 -0.392364  0.513360 -1.237322 -0.402556  0.474908
# 2172  1684  1.218844  0.183157  0.968741  1.039487 -0.607498 -0.326604
# 361    265  0.073631  1.051207 -0.281223  0.853749  1.065966  1.219197
# 2942  2487  1.371927 -0.598738  0.486478 -0.441599 -1.133701 -0.818759
# ...    ...       ...       ...       ...       ...       ...       ...
# 1642  1268 -2.581234  0.668009 -0.727711 -1.970741 -0.334986 -1.194353
# 713    537 -1.097278  1.094348  2.074334 -0.085776 -0.200635 -0.424142
# 951    720  1.130922  0.246743  0.554945  0.996969 -0.229634 -0.219428
# 2946  2494 -1.002093 -0.567988  2.776545 -1.247239 -0.990410  0.961362
# 706    533 -1.233535  0.145320 -0.067227 -1.750577 -0.801069 -0.381652
#
#             V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(x_train.shape, x_test.shape)
# Out:
# (370, 30) (124, 30)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
x_train_predict = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_predict,y_train)
print("The model's training Accuracy is : {round(training_data_accuracy * 100,2)}% ")
# Out:
# The model's training Accuracy is : {round(training_data_accuracy * 100,2)}%

# %%
x_test_predict = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_predict,y_test)
print("The model's testing Accuracy is : {round(test_data_accuracy * 100,2)}% ")
# Out:
# The model's testing Accuracy is : {round(test_data_accuracy * 100,2)}%

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-11732b5a7d5f> in <cell line: 1>()
# ----> 1 ax = ConfusionMatrixDisplay.from_predictions(x_test,y_test)
#       2
#       3 plt.show()
#
# NameError: name 'ConfusionMatrixDisplay' is not defined
